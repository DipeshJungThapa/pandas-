# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# dir(pd)

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
# ...

# %%
fifa=pd.read_clipboard()

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 1     1      Brazil              21       5  109  73  18  18  229  105  124
# 2     4   Argentina              17       2   81  43  15  23  137   93   44
# 3     3       Italy              18       4   83  45  21  17  128   77   51
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     8     Uruguay              13       2   56  24  12  20   87   74   13
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     6     England              15       1   69  29  21  19   91   64   27
#
#    Pts
# 0  221
# 1  237
# 2  144
# 3  156
# 4  115
# 5   84
# 6  105
# 7  108

# %%
type(fifa)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(fifa)
# Out:
# ['D',
#  'GA',
#  'GD',
#  'GF',
#  'L',
#  'Participations',
#  'Pld',
#  'Pts',
#  'Rank',
#  'T',
#  'Team',
#  'Titles',
#  'W',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
fifa.GA
# Out:
# 0    105
# 1    125
# 2     77
# 3     93
# 4     77
# 5     64
# 6     72
# 7     74
# Name: GA, dtype: int64

# %%
fifa.W
# Out:
# 0    73
# 1    67
# 2    45
# 3    43
# 4    34
# 5    29
# 6    30
# 7    24
# Name: W, dtype: int64

# %%
fifa.count
# Out:
# <bound method DataFrame.count of    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84  >

# %%
len(fifa)
# Out:
# 8

# %%
fifa.columns
# Out:
# Index(['Rank', 'Team', 'Participations', 'Titles', 'Pld', 'W', 'D', 'L', 'GF',
#        'GA', 'GD', 'Pts'],
#       dtype='object')

# %%
fifa.columns[-7]
# Out:
# 'W'

# %%
fifa.plot()
# Out:
# <AxesSubplot: >

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            8 non-null      int64
#  1   Team            8 non-null      object
#  2   Participations  8 non-null      int64
#  3   Titles          8 non-null      int64
#  4   Pld             8 non-null      int64
#  5   W               8 non-null      int64
#  6   D               8 non-null      int64
#  7   L               8 non-null      int64
#  8   GF              8 non-null      int64
#  9   GA              8 non-null      int64
#  10  GD              8 non-null      int64
#  11  Pts             8 non-null      int64
# dtypes: int64(11), object(1)
# memory usage: 896.0+ bytes

# %%
fifa.head()
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115

# %%
fifa.head(2)
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
#
#    Pts
# 0  237
# 1  221

# %%
fifa.head(-2)
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108

# %%
fifa.tail()
# Out:
#    Rank       Team  Participations  Titles  Pld   W   D   L   GF  GA  GD  Pts
# 3     4  Argentina              17       2   81  43  15  23  137  93  44  144
# 4     5     France              15       2   66  34  13  19  120  77  43  115
# 5     6    England              15       1   69  29  21  19   91  64  27  108
# 6     7      Spain              15       1   63  30  15  18   99  72  27  105
# 7     8    Uruguay              13       2   56  24  12  20   87  74  13   84

# %%
fifa.tail(0)
# Out:
# Empty DataFrame
# Columns: [Rank, Team, Participations, Titles, Pld, W, D, L, GF, GA, GD, Pts]
# Index: []

# %%
fifa.tail(1)
# Out:
#    Rank     Team  Participations  Titles  Pld   W   D   L  GF  GA  GD  Pts
# 7     8  Uruguay              13       2   56  24  12  20  87  74  13   84

# %%
fifa.describe()
# Out:
#           Rank  Participations    Titles         Pld          W          D  \
# count  8.00000        8.000000  8.000000    8.000000   8.000000   8.000000
# mean   4.50000       16.625000  2.625000   79.500000  43.125000  16.875000
# std    2.44949        2.615203  1.505941   20.255511  18.074746   3.603074
# min    1.00000       13.000000  1.000000   56.000000  24.000000  12.000000
# 25%    2.75000       15.000000  1.750000   65.250000  29.750000  14.500000
# 50%    4.50000       16.000000  2.000000   75.000000  38.500000  16.500000
# 75%    6.25000       18.250000  4.000000   89.500000  50.500000  20.250000
# max    8.00000       21.000000  5.000000  109.000000  73.000000  21.000000
#
#                L          GF          GA          GD         Pts
# count   8.000000    8.000000    8.000000    8.000000    8.000000
# mean   19.500000  139.625000   85.875000   53.750000  146.250000
# std     2.070197   57.021143   20.413144   38.688315   55.984054
# ...

# %%
fifa.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_59588\865204359.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   fifa.mean()
# Rank                4.500
# Participations     16.625
# Titles              2.625
# Pld                79.500
# W                  43.125
# D                  16.875
# L                  19.500
# GF                139.625
# GA                 85.875
# GD                 53.750
# Pts               146.250
# dtype: float64

# %%
dir(fifa)
# Out:
# ['D',
#  'GA',
#  'GD',
#  'GF',
#  'L',
#  'Participations',
#  'Pld',
#  'Pts',
#  'Rank',
#  'T',
#  'Team',
#  'Titles',
#  'W',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
fifa['Titles']
# Out:
# 0    5
# 1    4
# 2    4
# 3    2
# 4    2
# 5    1
# 6    1
# 7    2
# Name: Titles, dtype: int64

# %%
max(fifa['Titles'])
# Out:
# 5

# %%
min(fifa['Titles'])
# Out:
# 1

# %%
fifa['Titles'].plot()
# Out:
# <AxesSubplot: >

# %%
fifa['Titles'].plot(kind="pie")
# Out:
# <AxesSubplot: ylabel='Titles'>

# %%
fifa['Titles'].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
fifa[['Titles','Team']]
# Out:
#    Titles        Team
# 0       5      Brazil
# 1       4  Germany[a]
# 2       4       Italy
# 3       2   Argentina
# 4       2      France
# 5       1     England
# 6       1       Spain
# 7       2     Uruguay

# %%
fifa[['Titles','Team']].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 fifa[['Titles','Team']].plot(kind="pie")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:951, in PlotAccessor.__call__(self, *args, **kwargs)
#     949 if isinstance(data, ABCDataFrame):
#     950     if y is None and kwargs.get("subplots") is False:
# --> 951         raise ValueError(
#     952             f"{kind} requires either y column or 'subplots=True'"
#     953         )
#     954     elif y is not None:
#     955         if is_integer(y) and not data.columns.holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 fifa[fifa['W']<=5][['team','wins']]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
# ...

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84

# %%
fifa[(fifa['Titles']>2) & (fifa['Pld']>15)]
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
#
#    Pts
# 0  237
# 1  221
# 2  156

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 fifa.team()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'team'

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84

# %%
fifa[fifa['Titles']<2][['L','D']]
# Out:
#     L   D
# 5  19  21
# 6  18  15

# %%
x=fifa[fifa['Titles']<2][['W','L']].plot()

# %%
y=fifa[fifa['Titles']<2][['D','L']].plot()

# %%
x=fifa[fifa['Titles']<2][['W','GA']].plot()

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84

# %%
x=fifa[fifa['Titles']<2][['W','L']].plot(kind="bar")

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84

# %%
fifa[fifa['Titles']<2][['W','L']].plot()
# Out:
# <AxesSubplot: >

# %%
FootBALLDATA =fifa[fifa['Titles']<2][['W','L']].plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 FootBALLDATA =fifa[fifa['Titles']<2][['W','L']].plot(kind="pie")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:951, in PlotAccessor.__call__(self, *args, **kwargs)
#     949 if isinstance(data, ABCDataFrame):
#     950     if y is None and kwargs.get("subplots") is False:
# --> 951         raise ValueError(
#     952             f"{kind} requires either y column or 'subplots=True'"
#     953         )
#     954     elif y is not None:
#     955         if is_integer(y) and not data.columns.holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
fifa[fifa['Titles']<2][['W','L','D','GA']].plot()
# Out:
# <AxesSubplot: >

# %%
x= fifa[fifa['Titles']<4][['L','W','D','GA']].plot(kind="bar")

# %%
fifa
# Out:
#    Rank        Team  Participations  Titles  Pld   W   D   L   GF   GA   GD  \
# 0     1      Brazil              21       5  109  73  18  18  229  105  124
# 1     2  Germany[a]              19       4  109  67  20  22  226  125  101
# 2     3       Italy              18       4   83  45  21  17  128   77   51
# 3     4   Argentina              17       2   81  43  15  23  137   93   44
# 4     5      France              15       2   66  34  13  19  120   77   43
# 5     6     England              15       1   69  29  21  19   91   64   27
# 6     7       Spain              15       1   63  30  15  18   99   72   27
# 7     8     Uruguay              13       2   56  24  12  20   87   74   13
#
#    Pts
# 0  237
# 1  221
# 2  156
# 3  144
# 4  115
# 5  108
# 6  105
# 7   84

# %%
x= fifa[fifa['Titles']<4][['L','W','D','GA']].plot(kind="bar")
plt.title("Teams with less than 4 titles")
plt.xlable("teams")
plt.ylable("titles")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 3
#       1 x= fifa[fifa['Titles']<4][['L','W','D','GA']].plot(kind="bar")
#       2 plt.title("Teams with less than 4 titles")
# ----> 3 plt.xlable("teams")
#       4 plt.ylable("titles")
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'
